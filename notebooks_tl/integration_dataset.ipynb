# %%
import os
os.chdir("D:/Violence_detection")
print(os.getcwd())
# Out:
# D:\Violence_detection

# %%
import os

folder = r"violent\cam1"

files = sorted(os.listdir(folder))

start_number = 1001

for i, file in enumerate(files):

    if file.endswith(".mp4"):

        old_path = os.path.join(folder, file)
        new_name = f"V_{start_number + i}.mp4"
        new_path = os.path.join(folder, new_name)

        os.rename(old_path, new_path)

print("Renaming completed")
# Out:
# Renaming completed

# %%
import os

folder = r"violent\cam2"

files = sorted(os.listdir(folder))

start_number = 1116

for i, file in enumerate(files):

    if file.endswith(".mp4"):

        old_path = os.path.join(folder, file)
        new_name = f"V_{start_number + i}.mp4"
        new_path = os.path.join(folder, new_name)

        os.rename(old_path, new_path)

print("Renaming completed")
# Out:
# Renaming completed

# %%
import os

folder = r"non-violent\cam1"

files = sorted(os.listdir(folder))

start_number = 1001

for i, file in enumerate(files):

    if file.endswith(".mp4"):

        old_path = os.path.join(folder, file)
        new_name = f"NV_{start_number + i}.mp4"
        new_path = os.path.join(folder, new_name)

        os.rename(old_path, new_path)

print("Cam1 renaming completed")
# Out:
# Cam1 renaming completed

# %%
folder = r"non-violent\cam2"

files = sorted(os.listdir(folder))

start_number = 1061

for i, file in enumerate(files):

    if file.endswith(".mp4"):

        old_path = os.path.join(folder, file)
        new_name = f"NV_{start_number + i}.mp4"
        new_path = os.path.join(folder, new_name)

        os.rename(old_path, new_path)

print("Cam2 renaming completed")
# Out:
# Cam2 renaming completed
